# %% [markdown]
# # Introduction
# In this project we will be compare the classification models,
#
# those classification models are
#
# 1. Decision Tree Classifier
# 2. Random Forest Classifier
# 3. KNN Classifier
# 4. Logistic Regression
# 5. SVM Classifier
#
# Problem statement: Create a classification model to predict the gender (male or
# female) based on different acoustic parameters

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading data

# %%
df=pd.read_csv("voice.csv")

# %%
df.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %%
df.shape
# Out:
# (3168, 21)

# %% [markdown]
# # Different attributes

# %%
print(df.columns)
# Out:
# Index(['meanfreq', 'sd', 'median', 'Q25', 'Q75', 'IQR', 'skew', 'kurt',
#        'sp.ent', 'sfm', 'mode', 'centroid', 'meanfun', 'minfun', 'maxfun',
#        'meandom', 'mindom', 'maxdom', 'dfrange', 'modindx', 'label'],
#       dtype='object')

# %% [markdown]
# # Checking null values

# %%
df.isnull().sum()
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# label       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3168 entries, 0 to 3167
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  3168 non-null   float64
#  1   sd        3168 non-null   float64
#  2   median    3168 non-null   float64
#  3   Q25       3168 non-null   float64
#  4   Q75       3168 non-null   float64
#  5   IQR       3168 non-null   float64
#  6   skew      3168 non-null   float64
#  7   kurt      3168 non-null   float64
#  8   sp.ent    3168 non-null   float64
#  9   sfm       3168 non-null   float64
#  10  mode      3168 non-null   float64
#  11  centroid  3168 non-null   float64
#  12  meanfun   3168 non-null   float64
#  13  minfun    3168 non-null   float64
#  14  maxfun    3168 non-null   float64
#  15  meandom   3168 non-null   float64
#  16  mindom    3168 non-null   float64
#  17  maxdom    3168 non-null   float64
#  18  dfrange   3168 non-null   float64
# ...

# %% [markdown]
# # Data insights and adding label to male and female

# %%
a=df.label.value_counts()
print(a)
print("Total: ",df.label.count())
# Out:
# male      1584
# female    1584
# Name: label, dtype: int64
# Total:  3168

# %%
df.corr() #correlation between the various input variables
# Out:
#           meanfreq        sd    median       Q25       Q75       IQR  \
# meanfreq  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# sd       -0.739039  1.000000 -0.562603 -0.846931 -0.161076  0.874660
# median    0.925445 -0.562603  1.000000  0.774922  0.731849 -0.477352
# Q25       0.911416 -0.846931  0.774922  1.000000  0.477140 -0.874189
# Q75       0.740997 -0.161076  0.731849  0.477140  1.000000  0.009636
# IQR      -0.627605  0.874660 -0.477352 -0.874189  0.009636  1.000000
# skew     -0.322327  0.314597 -0.257407 -0.319475 -0.206339  0.249497
# kurt     -0.316036  0.346241 -0.243382 -0.350182 -0.148881  0.316185
# sp.ent   -0.601203  0.716620 -0.502005 -0.648126 -0.174905  0.640813
# sfm      -0.784332  0.838086 -0.661690 -0.766875 -0.378198  0.663601
# mode      0.687715 -0.529150  0.677433  0.591277  0.486857 -0.403764
# centroid  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# meanfun   0.460844 -0.466281  0.414909  0.545035  0.155091 -0.534462
# ...

# %% [markdown]
# # our label feature has 2 valuble which are male and female. these are string but we need integers for classification therefore ,we must convert them from object to integer.

# %%
df.label=[1 if each=="female" else 0 for each in df.label]

# %%
df.label
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3163    1
# 3164    1
# 3165    1
# 3166    1
# 3167    1
# Name: label, Length: 3168, dtype: int64

# %% [markdown]
# # spliting data set into training set and testing set

# %%
y=df.label.values
x=df.drop(['label'],axis='columns')
from sklearn.model_selection import train_test_split #import class for spliting
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=50)
#Hfere the size is 20%
algo_names=[]
algo_scores=[]

# %%
x_train.shape
# Out:
# (2534, 20)

# %%
x_test.shape
# Out:
# (634, 20)

# %%
x_train.head()
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 974   0.188291  0.060757  0.196792  0.128553  0.243459  0.114906  1.924342
# 2769  0.187396  0.044700  0.185598  0.171349  0.206260  0.034911  2.454544
# 1805  0.177266  0.033878  0.175619  0.166018  0.188938  0.022920  3.261121
# 175   0.134962  0.062047  0.111388  0.088780  0.189571  0.100791  2.317095
# 1919  0.097562  0.070847  0.071001  0.038766  0.158224  0.119458  1.430850
#
#            kurt    sp.ent       sfm      mode  centroid   meanfun    minfun  \
# 974    6.921315  0.898536  0.359334  0.117107  0.188291  0.130205  0.048096
# 2769   9.671798  0.878222  0.354332  0.174198  0.187396  0.155880  0.048534
# 1805  14.297520  0.816742  0.226999  0.164469  0.177266  0.164342  0.020833
# 175    9.072179  0.931091  0.560896  0.104794  0.134962  0.086565  0.016277
# 1919   4.652448  0.952220  0.664712  0.038555  0.097562  0.148914  0.019851
#
# ...

# %%
x_train.tail()
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 2014  0.142297  0.083138  0.169747  0.058402  0.217596  0.159194   1.963700
# 2157  0.183551  0.033172  0.187811  0.178004  0.196637  0.018634   3.361455
# 1931  0.162205  0.069786  0.182035  0.136821  0.210530  0.073709   4.105541
# 1504  0.117170  0.076995  0.108125  0.050000  0.201406  0.151406  10.649260
# 1712  0.240844  0.053585  0.256984  0.236169  0.268792  0.032623   3.203079
#
#             kurt    sp.ent       sfm      mode  centroid   meanfun    minfun  \
# 2014    7.248161  0.955880  0.700716  0.229604  0.142297  0.178167  0.017877
# 2157   14.422563  0.785318  0.235786  0.192715  0.183551  0.177953  0.060377
# 1931   35.655663  0.930920  0.575286  0.000000  0.162205  0.149335  0.027257
# 1504  228.008040  0.944999  0.653185  0.000000  0.117170  0.111191  0.015640
# 1712   14.252101  0.824963  0.201548  0.268392  0.240844  0.225755  0.062745
#
# ...

# %% [markdown]
# # Applying different models

# %% [raw]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
#import decision tree classifier
dec_tree= DecisionTreeClassifier(random_state=50)
dec_tree.fit(x_train,y_train)
print("Decision Tree classification score:",dec_tree.score(x_test,y_test))#to print the accuracy
algo_names.append("Decision Tree")
algo_scores.append(dec_tree.score(x_test,y_test))
p1=dec_tree.predict(x_test)
# Out:
# Decision Tree classification score: 0.9511041009463722

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
#import random forest classifier
rand_forest= RandomForestClassifier(random_state=50)
rand_forest.fit(x_train,y_train)
print("Random Forest classifier score: ",rand_forest.score(x_test,y_test))
algo_names.append("Random forest")
algo_scores.append(rand_forest.score(x_test,y_test))
p2=rand_forest.predict(x_test)
# Out:
# Random Forest classifier score:  0.973186119873817

# %% [markdown]
# Svm classifier

# %%
from sklearn.svm import SVC
#import the svc class
svm=SVC(random_state=50)
svm.fit(x_train,y_train)
print("SVM classifier score is {}".format(svm.score(x_test,y_test)))
algo_names.append("SVM")
algo_scores.append(svm.score(x_test,y_test))
p3=svm.predict(x_test)
# Out:
# SVM classifier score is 0.6750788643533123

# %% [markdown]
# KNN classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 1)
#when n_neighbors = 1 we get the maximum accuracy of the KNN Classifier
knn.fit(x_train, y_train)
print("KNN Classifier score is {}".format(knn.score(x_test,y_test)))
algo_names.append("KNN")
algo_scores.append(knn.score(x_test,y_test))
p4=knn.predict(x_test)
# Out:
# KNN Classifier score is 0.7429022082018928
# C:\Users\Eakeshd\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
print("Logistic Regression score is {}".format(lr.score(x_test,y_test)))
algo_names.append("Logistic Regression")
algo_scores.append(lr.score(x_test,y_test))
p5=lr.predict(x_test)
# Out:
# Logistic Regression score is 0.9100946372239748
# C:\Users\Eakeshd\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # Comparing the classification score of different algorithms using Bar Graph

# %%
plt.figure(figsize=(12,10))
plt.ylim([0.60,1])
plt.bar(algo_names,algo_scores,width=0.5,color=['green'])
plt.xlabel('Algorithm Name')
plt.ylabel('Algorithm score')
# Out:
# Text(0, 0.5, 'Algorithm score')

# %% [markdown]
# # Printing the classification report of different models used using sklearn.metrics library and classification report function.

# %%
from sklearn.metrics import classification_report
#import the exact function

# %% [markdown]
# Decision tree classification report

# %%
report_dec_tree=classification_report(y_test,p1)
print(report_dec_tree)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       310
#            1       0.95      0.95      0.95       324
#
#     accuracy                           0.95       634
#    macro avg       0.95      0.95      0.95       634
# weighted avg       0.95      0.95      0.95       634

# %% [markdown]
# Random Forest classification report

# %%
report_random_forest=classification_report(y_test,p2)
print(report_random_forest)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       310
#            1       0.97      0.98      0.97       324
#
#     accuracy                           0.97       634
#    macro avg       0.97      0.97      0.97       634
# weighted avg       0.97      0.97      0.97       634

# %% [markdown]
# SVM classification report

# %%
report_svm=classification_report(y_test,p3)
print(report_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.83      0.71       310
#            1       0.77      0.52      0.62       324
#
#     accuracy                           0.68       634
#    macro avg       0.70      0.68      0.67       634
# weighted avg       0.70      0.68      0.67       634

# %% [markdown]
# KNN classification report

# %%
report_knn=classification_report(y_test,p4)
print(report_knn)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.75      0.74       310
#            1       0.76      0.73      0.74       324
#
#     accuracy                           0.74       634
#    macro avg       0.74      0.74      0.74       634
# weighted avg       0.74      0.74      0.74       634

# %% [markdown]
# Logistic Regression

# %%
report_lr=classification_report(y_test,p5)
print(report_lr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91       310
#            1       0.96      0.86      0.91       324
#
#     accuracy                           0.91       634
#    macro avg       0.91      0.91      0.91       634
# weighted avg       0.92      0.91      0.91       634

# %% [markdown]
# # Plotting pie charts for the wrong Vs correct predictions of each model

# %% [markdown]
# Decision tree pie chart

# %%
comp1=[31.7,602.3]
l1=['Predicted wrong','predicted correct']
plt.pie(comp1,labels=l1,autopct='%0.1f%%',colors=['red','pink'])
plt.title('DECISION TREE PREDICTION')
plt.show()

# %% [markdown]
# Random Forest Prediction pie chart

# %%
comp1=[17.1,616.8]
l1=['Predicted wrong','predicted correct']
plt.pie(comp1,labels=l1,autopct='%0.1f%%',colors=['red','pink'])
plt.title('RANDOM FOREST PREDICTION')
plt.show()

# %% [markdown]
# SVM prediction pie chart

# %%
comp1=[206.05,427.9]
l1=['Predicted wrong','predicted correct']
plt.pie(comp1,labels=l1,autopct='%0.1f%%',colors=['red','pink'])
plt.title('SVM PREDICTION')
plt.show()

# %% [markdown]
# KNN Prediction pie chart

# %%
comp1=[163.5,470.4]
l1=['Predicted wrong','predicted correct']
plt.pie(comp1,labels=l1,autopct='%0.1f%%',colors=['red','pink'])
plt.title('DECISION TREE PREDICTION')
plt.show()

# %% [markdown]
# Logistic Regression

# %%
comp1=[58.3,575.6]
l1=['Predicted wrong','predicted correct']
plt.pie(comp1,labels=l1,autopct='%0.1f%%',colors=['red','pink'])
plt.title('DECISION TREE PREDICTION')
plt.show()

# %% [markdown]
# # Plotting confusion matrix using sklearn.metrics.onfusion_matrix and heatmap of seaborn library

# %%
from sklearn.metrics import confusion_matrix
#importing modules

# %% [markdown]
# Decision Tree confusion Matrix

# %%
conf_mat1=confusion_matrix(y_test,p1)
plt.figure(figsize=(6,6))
sns.heatmap(conf_mat1,annot=True,fmt=".0f")
plt.ylabel("ACTUAL")
plt.xlabel("PREDICTION")
plt.title("DECISION TREE CONFUSION MATRIX")
plt.show()

# %% [markdown]
# Random Forest confusion matrix

# %%
conf_mat2=confusion_matrix(y_test,p2)
plt.figure(figsize=(6,6))
sns.heatmap(conf_mat2,annot=True,fmt=".0f")
plt.ylabel("ACTUAL")
plt.xlabel("PREDICTION")
plt.title("RANDOM FOREST CONFUSION MATRIX")
plt.show()

# %% [markdown]
# SVM Confusion Matrix

# %%
conf_mat3=confusion_matrix(y_test,p3)
plt.figure(figsize=(6,6))
sns.heatmap(conf_mat3,annot=True,fmt=".0f")
plt.ylabel("ACTUAL")
plt.xlabel("PREDICTION")
plt.title("SVM CONFUSION MATRIX")
plt.show()

# %% [markdown]
# KNN confusion matrix

# %%
conf_mat4=confusion_matrix(y_test,p4)
plt.figure(figsize=(6,6))
sns.heatmap(conf_mat4,annot=True,fmt=".0f")
plt.ylabel("ACTUAL")
plt.xlabel("PREDICTION")
plt.title("KNN CONFUSION MATRIX")
plt.show()

# %% [markdown]
# Logistic Regression

# %%
conf_mat5=confusion_matrix(y_test,p5)
plt.figure(figsize=(6,6))
sns.heatmap(conf_mat5,annot=True,fmt=".0f")
plt.ylabel("ACTUAL")
plt.xlabel("PREDICTION")
plt.title("LOGISTIC REGRESSION CONFUSION MATRIX")
plt.show()

# %% [markdown]
# # Plotting roc curve for differnt models using roc_curve of sklearn.metrics

# %% [markdown]
# Decision Tree Roc Curve

# %%
from sklearn.metrics import roc_curve,roc_auc_score,auc
b=[]
probs1=dec_tree.predict_proba(x_test)
preds1=probs1[:,1]
fpr1,tpr1,threshold1=roc_curve(y_test,preds1)
roc_auc1=auc(fpr1,tpr1)
plt.title('Recevier Operating Characteristic')
plt.plot(fpr1,tpr1,'b',label='AUC=%0.2f' %roc_auc1)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.ylabel('True positive rate')
plt.xlabel('False positive rate')
plt.title("Decision Tree Roc curve")
plt.show()
b.append(roc_auc1)
print("DECISION TREE AUC :",roc_auc_score(y_test,preds1))
# Out:
# DECISION TREE AUC : 0.951115093588212

# %% [markdown]
# Random Forest Roc Curve

# %%
probs2=rand_forest.predict_proba(x_test)
preds2=probs2[:,1]
fpr2,tpr2,threshold2=roc_curve(y_test,preds2)
roc_auc2=auc(fpr2,tpr2)
plt.title('Recevier Operating Characteristic')
plt.plot(fpr2,tpr2,'b',label='AUC=%0.2f' %roc_auc2)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.ylabel('True positive rate')
plt.xlabel('False positive rate')
plt.title("Random Forest Roc curve")
plt.show()
b.append(roc_auc2)
print("RANDOM FOREST AUC :",roc_auc_score(y_test,preds2))
# Out:
# RANDOM FOREST AUC : 0.9950766626841895

# %% [markdown]
# SVM Roc Curve

# %%
fpr3,tpr3,threshold3=roc_curve(y_test,p3)
roc_auc3=auc(fpr3,tpr3)
plt.title('Recevier Operating Characteristic')
plt.plot(fpr3,tpr3,'b',label='AUC=%0.2f' %roc_auc3)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.ylabel('True positive rate')
plt.xlabel('False positive rate')
plt.title("SVM Roc curve")
plt.show()
b.append(roc_auc3)
print("SVM AUC :",roc_auc_score(y_test,p3))
# Out:
# SVM AUC : 0.6784747112704103

# %% [markdown]
# KNN Roc Curve

# %%
probs4=knn.predict_proba(x_test)
preds4=probs4[:,1]
fpr4,tpr4,threshold4=roc_curve(y_test,preds4)
roc_auc4=auc(fpr4,tpr4)
plt.title('Recevier Operating Characteristic')
plt.plot(fpr4,tpr4,'b',label='AUC=%0.2f' %roc_auc4)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.ylabel('True positive rate')
plt.xlabel('False positive rate')
plt.title("KNN Roc curve")
plt.show()
b.append(roc_auc4)
print("KNN AUC :",roc_auc_score(y_test,preds4))
# Out:
# KNN AUC : 0.7430904022301872

# %% [markdown]
# Logistic Regression

# %%
probs5=lr.predict_proba(x_test)
preds5=probs5[:,1]
fpr5,tpr5,threshold5=roc_curve(y_test,preds5)
roc_auc5=auc(fpr5,tpr5)
plt.title('Recevier Operating Characteristic')
plt.plot(fpr5,tpr5,'b',label='AUC=%0.2f' %roc_auc4)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.ylabel('True positive rate')
plt.xlabel('False positive rate')
plt.title("LOGISTIC REGRESSION ROC CURVE")
plt.show()
b.append(roc_auc5)
print("KNN AUC :",roc_auc_score(y_test,preds5))
# Out:
# KNN AUC : 0.938590203106332

# %% [markdown]
# # Comparing area under curve for all models using line graph

# %%
a=["Decision Tree","Random Forest","SVM","KNN","Logistic Regression"]
plt.plot(a,b,color='red')
plt.title("AUC OF ALL MODELS")
plt.xlabel("MODEL")
plt.ylabel("AUC SCORE")
plt.show()

# %% [markdown]
# CONCULSION : BASED ON THE RESULTS OF THE PIE CHARTS AND CONFUSION_MATRIX AND CLASSIFICATION REPORT WE CAN SAY THAT THE RANDOM FOREST CLASSIFICATION IS THE BEST SUITED FOR THIS PROBLEM WHERE WE ARE PREDICTING THE PERSON AS MALE/FEMALE BASED ON THE DIFFERENT ACOUSTIC PARAMETERS

# %% [markdown]
# Note: Execute all snippets linearly don't execute in between
